# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests
import json

# %%
# Poloniex Prices
prices = requests.get("https://api.poloniex.com/markets/price")
prices_list = []
if prices.status_code == 200:
  prices_json = json.loads(prices.text)
  for p in prices_json:
    prices_list.append({"ticker": p["symbol"], "price": p["price"]})

# %%
print(prices_list)
# Out:
# [{'ticker': 'BTS_BTC', 'price': '0.0000000578'}, {'ticker': 'DASH_BTC', 'price': '0.000568'}, {'ticker': 'DOGE_BTC', 'price': '0.00000236'}, {'ticker': 'LTC_BTC', 'price': '0.001251'}, {'ticker': 'XLM_BTC', 'price': '0.000002025'}, {'ticker': 'XEM_BTC', 'price': '0.000000537'}, {'ticker': 'XMR_BTC', 'price': '0.002112'}, {'ticker': 'XRP_BTC', 'price': '0.00000905'}, {'ticker': 'BTC_USDT', 'price': '66873.26'}, {'ticker': 'DASH_USDT', 'price': '38.07'}, {'ticker': 'LTC_USDT', 'price': '83.633'}, {'ticker': 'XLM_USDT', 'price': '0.1351'}, {'ticker': 'XMR_USDT', 'price': '140.66'}, {'ticker': 'XRP_USDT', 'price': '0.604'}, {'ticker': 'ETH_BTC', 'price': '0.05679'}, {'ticker': 'ETH_USDT', 'price': '3795.09'}, {'ticker': 'SC_BTC', 'price': '0.0000001318'}, {'ticker': 'DCR_BTC', 'price': '0.000325'}, {'ticker': 'LSK_BTC', 'price': '0.00002198'}, {'ticker': 'STEEM_BTC', 'price': '0.00000435'}, {'ticker': 'ETC_BTC', 'price': '0.000554'}, {'ticker': 'ETC_ETH', 'price': '0.01084'}, {'ticker': 'ETC_USDT', 'price': '37.013'}, {'ticker': 'ARDR_BTC', 'price': '0.000001549'}, {'ticker': 'ZEC_BTC', 'price': '0.00047'}, {'ticker': 'ZEC_ETH', 'price': '0.00805'}, {'ticker': 'ZEC_USDT', 'price': '31.37'}, {'ticker': 'ZRX_BTC', 'price': '0.000007'}, {'ticker': 'ZRX_ETH', 'price': '0.0001255'}, {'ticker': 'CVC_BTC', 'price': '0.000001627'}, {'ticker': 'OMG_BTC', 'price': '0.00001745'}, {'ticker': 'GAS_BTC', 'price': '0.0001048'}, {'ticker': 'STORJ_BTC', 'price': '0.000011'}, {'ticker': 'EOS_BTC', 'price': '0.00001535'}, {'ticker': 'EOS_ETH', 'price': '0.0002505'}, {'ticker': 'EOS_USDT', 'price': '1.0249'}, {'ticker': 'SNT_BTC', 'price': '0.000000685'}, {'ticker': 'KNC_BTC', 'price': '0.00001175'}, {'ticker': 'BAT_BTC', 'price': '0.00000447'}, {'ticker': 'BAT_USDT', 'price': '0.3113'}, {'ticker': 'LOOM_BTC', 'price': '0.00000151'}, {'ticker': 'DOGE_USDT', 'price': '0.159558'}, {'ticker': 'LSK_USDT', 'price': '1.826'}, {'ticker': 'SC_USDT', 'price': '0.00878'}, {'ticker': 'ZRX_USDT', 'price': '0.4757'}, {'ticker': 'QTUM_BTC', 'price': '0.0000738'}, {'ticker': 'QTUM_USDT', 'price': '4.625'}, {'ticker': 'BTC_USDC', 'price': '67057.87'}, {'ticker': 'ETH_USDC', 'price': '3809.93'}, {'ticker': 'USDT_USDC', 'price': '0.99988'}, {'ticker': 'MANA_BTC', 'price': '0.00000943'}, {'ticker': 'MANA_USDT', 'price': '0.6369'}, {'ticker': 'BNT_BTC', 'price': '0.00001126'}, {'ticker': 'BCHSV_BTC', 'price': '0.001494'}, {'ticker': 'BCHSV_USDC', 'price': '105'}, {'ticker': 'XRP_USDC', 'price': '0.5834'}, {'ticker': 'XMR_USDC', 'price': '146'}, {'ticker': 'XLM_USDC', 'price': '0.1388'}, {'ticker': 'DOGE_USDC', 'price': '0.18841'}, {'ticker': 'LTC_USDC', 'price': '83.14'}, {'ticker': 'ZEC_USDC', 'price': '30.62'}, {'ticker': 'NMR_BTC', 'price': '0.0004897'}, {'ticker': 'POLY_BTC', 'price': '0.000001999'}, {'ticker': 'LPT_BTC', 'price': '0.0002204'}, {'ticker': 'ATOM_BTC', 'price': '0.000186'}, {'ticker': 'ATOM_USDC', 'price': '12.66'}, {'ticker': 'ATOM_USDT', 'price': '12.498'}, {'ticker': 'DASH_USDC', 'price': '34.5'}, {'ticker': 'EOS_USDC', 'price': '1.0564'}, {'ticker': 'ETC_USDC', 'price': '35.48'}, {'ticker': 'BCHSV_USDT', 'price': '101.34'}, {'ticker': 'TRX_BTC', 'price': '0.000002056'}, {'ticker': 'TRX_USDC', 'price': '0.13718'}, {'ticker': 'TRX_USDT', 'price': '0.13743'}, {'ticker': 'ETH_TRX', 'price': '27668.52'}, {'ticker': 'XRP_TRX', 'price': '4.395'}, {'ticker': 'BTT_USDT', 'price': '0.0000017454'}, {'ticker': 'BTT_TRX', 'price': '0.00001285'}, {'ticker': 'WIN_USDT', 'price': '0.00018844'}, {'ticker': 'WIN_TRX', 'price': '0.001336'}, {'ticker': 'STEEM_TRX', 'price': '1.152'}, {'ticker': 'LINK_BTC', 'price': '0.0002943'}, {'ticker': 'LINK_TRX', 'price': '134.33'}, {'ticker': 'XTZ_BTC', 'price': '0.00002001'}, {'ticker': 'XTZ_USDT', 'price': '1.3505'}, {'ticker': 'XTZ_TRX', 'price': '8.94'}, {'ticker': 'USDJ_USDT', 'price': '1.1281'}, {'ticker': 'SNX_BTC', 'price': '0.0000635'}, {'ticker': 'SNX_USDT', 'price': '4.234'}, {'ticker': 'SNX_TRX', 'price': '30.26'},  ...

# %%
# Poloniex Orderbook
ticker = "DASH_BTC"
limit = 20
ob = requests.get(f"https://api.poloniex.com/markets/{ticker}/orderBook?limit={limit}")
ob_json = []
if ob.status_code == 200:
  ob_json = json.loads(ob.text)
print(ob_json)
# Out:
# {'time': 1709746364297, 'scale': '0.000001', 'asks': ['0.000574', '0.3', '0.000598', '0.02', '0.000599', '0.05', '0.0006', '50', '0.000609', '0.15', '0.000628', '0.08', '0.000629', '1.84', '0.000649', '0.05', '0.00065', '30', '0.000651', '2', '0.000658', '0.74', '0.000667', '0.08', '0.000668', '0.99', '0.000679', '0.05', '0.00068', '0.02', '0.000683', '0.05', '0.000684', '0.10', '0.000687', '0.02', '0.000689', '0.10', '0.000694', '0.10'], 'bids': ['0.000504', '5.20', '0.000503', '3.77', '0.000501', '0.04', '0.0005', '0.40', '0.000496', '0.11', '0.00048', '0.06', '0.000461', '0.97', '0.000441', '1.02', '0.00043', '2.75', '0.000421', '1.06', '0.000401', '1.12', '0.00035', '2', '0.000333', '30.03', '0.0003', '3.3', '0.000292', '34.24', '0.0001', '8.91', '0.000054', '36.09', '0.00003', '24', '0.00001', '1334.13', '0.000005', '50'], 'ts': 1709746364602}

# %%
# Structure our orderbook
asks = []
bids = []
for i in range(0, len(ob_json["asks"]), 2):
    ask_price = ob_json["asks"][i]
    ask_quantity = ob_json["asks"][i + 1]
    asks.append([ask_price, ask_quantity])
for i in range(0, len(ob_json["bids"]), 2):
    bid_price = ob_json["bids"][i]
    bid_quantity = ob_json["bids"][i + 1]
    bids.append([bid_price, bid_quantity])
print(asks)
print(bids)
# Out:
# [['0.000574', '0.3'], ['0.000598', '0.02'], ['0.000599', '0.05'], ['0.0006', '50'], ['0.000609', '0.15'], ['0.000628', '0.08'], ['0.000629', '1.84'], ['0.000649', '0.05'], ['0.00065', '30'], ['0.000651', '2'], ['0.000658', '0.74'], ['0.000667', '0.08'], ['0.000668', '0.99'], ['0.000679', '0.05'], ['0.00068', '0.02'], ['0.000683', '0.05'], ['0.000684', '0.10'], ['0.000687', '0.02'], ['0.000689', '0.10'], ['0.000694', '0.10']]
# [['0.000504', '5.20'], ['0.000503', '3.77'], ['0.000501', '0.04'], ['0.0005', '0.40'], ['0.000496', '0.11'], ['0.00048', '0.06'], ['0.000461', '0.97'], ['0.000441', '1.02'], ['0.00043', '2.75'], ['0.000421', '1.06'], ['0.000401', '1.12'], ['0.00035', '2'], ['0.000333', '30.03'], ['0.0003', '3.3'], ['0.000292', '34.24'], ['0.0001', '8.91'], ['0.000054', '36.09'], ['0.00003', '24'], ['0.00001', '1334.13'], ['0.000005', '50']]

# %%
# Binance
symbol = "BTCUSDT"
interval = "1d"
candles = requests.get(f"https://api.binance.com/api/v3/klines?symbol={symbol}&interval={interval}&limit={limit}")
candles_json = []
if candles.status_code == 200:
  candles_json = json.loads(candles.text)
  print(candles_json)

# %%
# Structure close prices
my_candles = []
for c in candles_json:
  my_candles.append(c[4])
print(my_candles)
print(len(my_candles))
# Out:
# []
# 0
